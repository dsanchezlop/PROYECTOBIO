# %%
import pandas as pd
import zipfile
import requests
from   pathlib import Path

# url para hacer request
# https://figshare.com/ndownloader/articles/19105049/versions/1

# %%
current_dir: Path = Path(__file__).parent
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [7], line 1
# ----> 1 current_dir: Path = Path(__file__).parent
#
# NameError: name '__file__' is not defined

# %%
url = "https://figshare.com/ndownloader/articles/19105049/versions/1"
ruta_destino: Path = current_dir

response = requests.get(url)

with open(ruta_destino, "wb") as archivo:
    archivo.write(response.content)

# with open("datos.csv", "wb") as f:
    # f.write(response.content)

# %%
data = pd.read_csv('nit_by_flora.csv')
data = data.drop(['DOI', 'Repetitions', 'Experimental.design', 'Paper', 'W_CV', 'W_LSD', 'W_SE_min', 'W_SE_Max', 'Row_Space', 'Water_applied', 'Sampling_time', 'Observation',
                  'Nobs%', 'Npred%', 'Nconc_LSD', 'Nupt_kg_ha', 'Nconc_SE_min', 'Nconc_SE_Max', 'Nupt_SE_min', 'Nupt_SE_Max', 'W_ton_ha'], axis=1)
data['Year'] = data['Year'].str.replace('Autumn ', '')
data['Year'] = data['Year'].str.replace('Early spring ', '')
data['Year'] = data['Year'].str.replace('Summer ', '')
data['Year'] = data['Year'].str.replace('Late spring ', '')
data['Year'] = data['Year'].str.split(' - ').str[0]
data['Year'] = data['Year'].str.split('-2').str[0]
data['Year'] = data['Year'].str.split('/ ').str[0]
data['Year'] = data['Year'].str.replace('/2007', '')

data = data.dropna(subset=['Year'])
data = data.dropna(subset=['Country'])
data = data.dropna(subset=['Treatment'])

data['Treatment'] = data['Treatment'].str.strip()
data['Water'] = data['Water'].fillna('No irrigation data')
data['Harvest_Date'] = data['Harvest_Date'].fillna('No harvest date data')
data['Sowing.Date'] = data['Sowing.Date'].fillna('No sowing date data')
data['Genotype'] = data['Genotype'].fillna('No genotype data')

display(data)
# Out:
#       Id          Species  Year    Country                           Sites  \
# 0      1  Annual ryegrass  1994  Argentina                          Tandil
# 1      1  Annual ryegrass  1994  Argentina                          Tandil
# 2      1  Annual ryegrass  1994  Argentina                          Tandil
# 3      1  Annual ryegrass  1994  Argentina                          Tandil
# 4      1  Annual ryegrass  1994  Argentina                          Tandil
# ...   ..              ...   ...        ...                             ...
# 4449  41    White cabbage  2001     Sweden  Torslunda Experimental Station
# 4450  41    White cabbage  2001     Sweden  Torslunda Experimental Station
# 4451  41    White cabbage  2001     Sweden  Torslunda Experimental Station
# 4452  41    White cabbage  2001     Sweden  Torslunda Experimental Station
# 4453  41    White cabbage  2001     Sweden  Torslunda Experimental Station
#
#      Treatment  Nrates_kg_ha Sowing.Date          Harvest_Date  \
# 0           N0             0       3-Mar  No harvest date data
# 1           N1            50       3-Mar  No harvest date data
# 2           N2           100       3-Mar  No harvest date data
# 3           N3           150       3-Mar  No harvest date data
# 4           N4           200       3-Mar  No harvest date data
# ...        ...           ...         ...                   ...
# 4449      N225           225   18 of May  No harvest date data
# 4450      N225           225   18 of May  No harvest date data
# 4451      N375           375   18 of May  No harvest date data
# 4452      N375           375   18 of May  No harvest date data
# 4453      N375           375   18 of May  No harvest date data
#
#                    Water         Genotype
# 0     No irrigation data  Grasslands Tama
# 1     No irrigation data  Grasslands Tama
# 2     No irrigation data  Grasslands Tama
# 3     No irrigation data  Grasslands Tama
# 4     No irrigation data  Grasslands Tama
# ...                  ...              ...
# 4449  No irrigation data           Heckla
# 4450  No irrigation data           Heckla
# 4451  No irrigation data           Heckla
# 4452  No irrigation data           Heckla
# 4453  No irrigation data           Heckla
#
# [4156 rows x 11 columns]

# %%
data_csv = data.to_csv("nit_by_flora_ed.csv", index=False)

# %%
data.isna().any()
# Out:
# Id              False
# Species         False
# Year            False
# Country         False
# Sites           False
# Treatment       False
# Nrates_kg_ha    False
# Sowing.Date     False
# Harvest_Date    False
# Water           False
# Genotype        False
# dtype: bool
